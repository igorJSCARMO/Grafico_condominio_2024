# %% [markdown]
# **BIBLIOTECAS**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# **PREENCHIMENTO / ATUALIZAÇÃO DE DADOS**

# %%
# Dados
categorias = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio' ]

Copasa =           [459.26, 501.22, 627.55, 606.77, 463.39]
Cemig =            [12, 59.23, 49.56, 40.26, 58.11]
Limpeza =          [150, 150, 150, 150, 150]
Material_Limpeza = [25, 25, 25, 25, 25]
Total =            [646.26, 735.45, 852.11, 822.03, 697.22]
Custo_Individual = [161.57, 183.86, 213.03, 205.51, 174.31]


# Criar dataFrame do gráfico
df = pd.DataFrame({
    'Copasa (R$)': Copasa,
    'Cemig (R$)': Cemig,
    'Limpeza (R$)': Limpeza,
    'Material Limpeza (R$)': Material_Limpeza,
}, index=categorias)

# Criar gráfico de barras empilhadas
ax = df.plot(kind='bar', stacked=True, figsize=(12, 8), zorder=2)

# Adicionar anotações aos pontos (opcional)
for i, valor in enumerate(Total):
    plt.text(i, valor + 5, str(valor), ha='center', va='bottom')

# Adicionar título e rótulos aos eixos
plt.title('Condomínio Ambrosina Sampaio 2024')
plt.xlabel('Meses')
plt.ylabel('Valores (R$)')

# Adicionar legenda
plt.legend(title='Categorias', loc='upper left')

# Rotacionar rótulos dos meses na vertical
plt.xticks(rotation=45)

# Adicionar grade ao gráfico com zorder mais alto
plt.grid(alpha=0.5, zorder=1)

# Salvando imagem do gráfico no windows (C:\Users\Igor CARMO)
plt.savefig('Condomínio Ambrosina Sampaio 2024.png')

# Mostrar o gráfico
plt.show()

# Criar dataFrame da tabela
df2 = pd.DataFrame({
    'Copasa (R$)': Copasa,
    'Cemig (R$)': Cemig,
    'Limpeza (R$)': Limpeza,
    'Material Limpeza (R$)': Material_Limpeza,
    'Total (R$)': Total,
    'Custo Individual (R$)': Custo_Individual,
})

df2.insert(0, 'Mês', ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio' ])

display(df2)
# Out:
#          Mês  Copasa (R$)  Cemig (R$)  Limpeza (R$)  Material Limpeza (R$)  \
# 0    Janeiro       459.26       12.00           150                     25
# 1  Fevereiro       501.22       59.23           150                     25
# 2      Março       627.55       49.56           150                     25
# 3      Abril       606.77       40.26           150                     25
# 4       Maio       463.39       58.11           150                     25
#
#    Total (R$)  Custo Individual (R$)
# 0      646.26                 161.57
# 1      735.45                 183.86
# 2      852.11                 213.03
# 3      822.03                 205.51
# 4      697.22                 174.31
